# %%
class cubo:
    def __init__(vertices,verticesOr,aristas, aristasOr):
        self.vertices=vertices
        self.verticeOr=verticesOr
        self.aristas=aristas
        self.aristasOr=aristasOr
        
    def D(self):
        aux=vertices[5]

        vertices[5]=verticesAux[8]
        vertices[8]=verticesAux[7]
        vertices[7]=verticesAux[6]
        vertices[6]=aux

        aux= verticesOr[5]
        verticesOr[5]=verticesOr[8]
        verticesOr[8]=verticesOr[7]
        verticesOr[7]=verticesOr[6]
        verticesOr[6]=aux
        

        aux=aristas[9]
        aristas[9]=aristas[10]
        aristas[10]=aristas[11]
        aristas[11]=aristas[12]
        aristas[12]=aux

        aux=aristasOr[9]
        aristasOr[9]=aristasOr[10]
        aristasOr[10]=aristasOr[11]
        aristasOr[11]=aristasOr[12]
        aristasOr[12]=aux
        
    def Di(self):
        self.D()
        self.D()
        self.D()

    def U(self):
        
        aux=vertices[1]
        vertices[1]=vertices[2]
        vertices[2]=vertices[3]
        vertices[3]=vertices[4]
        vertices[4]=aux
        
       
        aux=verticesOr[1]
        verticesOr[1]=verticesOr[2]
        verticesOr[2]=verticesOr[3]
        verticesOr[3]=verticesOr[4]
        verticesOr[4]=aux


        aux=aristas[1]
        aristas[1]=aristas[4]
        aristas[4]=aristas[3]
        aristas[3]=aristas[2]
        aristas[2]=aux

        aux=aristasOr[1]
        aristasOr[1]=aristasOr[4]
        aristasOr[4]=aristasOr[3]
        aristasOr[3]=aristasOr[2]
        aristasOr[2]=aux

    def Ui(self):
        self.U()
        self.U()
        self.U()
        
    def R(self):
        
        aux=vertices[2]
        vertices[2]=vertices[7] + 1
        vertices[7]=vertices[8] + 2
        vertices[8]=vertices[3] + 1
        vertices[3]=aux + 2

        aux=verticesOr[2]
        verticesOr[2]=(verticesOr[7] + 1)%3
        verticesOr[7]=(verticesOr[8] + 2)%3
        verticesOr[8]=(verticesOr[3] + 1)%3
        verticesOr[3]=(aux + 2)%3

        
        aux=aristas[2]
        aristas[2]=aristas[7]
        aristas[7]=aristas[10]
        aristas[10]=aristas[6]
        aristas[6]=aux
        
        aux= aristasOr[2]
        aristasOr[2]=aristasOr[7]
        aristasOr[7]=aristasOr[10]
        aristasOr[10]=aristasOr[6]
        aristasOr[6]=aux
        

    def Ri(self):
        self.R()
        self.R()
        self.R()
        
    def L(self):
        
        aux=vertices[1]
        vertices[1]=vertices[4]
        vertices[4]=vertices[5]
        vertices[5]=vertices[6]
        vertices[6]=aux

        aux=verticesOr[1]
        verticesOr[1]=(verticesOr[4] + 2)%3
        verticesOr[4]=(verticesOr[5] + 1)%3
        verticesOr[5]=(verticesOr[6] + 2)%3
        verticesOr[6]=(aux + 1)%3


        aux=aristas[4]
        aristas[4]=aristas[5]
        aristas[5]=aristas[12]
        aristas[12]=aristas[8]
        aristas[8]=aux

        aux=aristasOr[4]
        aristasOr[4]=aristasOr[5]
        aristasOr[5]=aristasOr[12]
        aristasOr[12]=aristasOr[8]
        aristasOr[8]=aux

    def Li(self):
        self.L()
        self.L()
        self.L()
        
    def F(self):
        
        aux=vertices[1]
        vertices[1]=verticesOr[6]
        vertices[6]=verticesOr[7]
        vertices[7]=verticesOr[2]
        vertices[2]=aux
        
        aux=verticesOr[1]
        verticesOr[1]=(verticesOr[6] + 1)%3
        verticesOr[6]=(verticesOr[7] + 2)%3
        verticesOr[7]=(verticesOr[2] + 1)%3
        verticesOr[2]=(aux + 2)%3
        

        aux=aristas[3]
        aristas[3]=aristas[8]
        aristas[8]=aristas[11]
        aristas[11]=aristas[7]
        aristas[7]=aux
        
        aux=aristasOr[3]
        aristasOr[3]=(aristasOr[8] + 1)%2
        aristasOr[8]=(aristasOr[11] + 1)%2
        aristasOr[11]=(aristasOr[7] + 1)%2
        aristasOr[7]=(aux + 1)%2
        

    def Fi(self):
        self.F()
        self.F()
        self.F()
        
    def B(self):
        
        
        aux=vertices[3]
        vertices[3]=vertices[8]
        vertices[8]=vertices[5]
        vertices[5]=vertices[4]
        vertices[4]=aux
        
        aux=verticesOr[3]
        verticesOr[3]=(verticesOr[8] + 1)%3
        verticesOr[8]=(verticesOr[5] + 2)%3
        verticesOr[5]=(verticesOr[4] + 1)%3
        verticesOr[4]=(aux + 2)%3
        
        
        aux=aristas[1]
        aristas[1]=aristas[6]
        aristas[6]=aristas[9]
        aristas[9]=aristas[5]
        aristas[5]=aux
        
        aux=aristasOr[1]
        aristasOr[1]=(aristasOr[6] + 1)%2
        aristasOr[6]=(aristasOr[9] + 1)%2
        aristasOr[9]=(aristasOr[5] + 1)%2
        aristasOr[5]=(aux + 1)%2
        
        
    def Bi(self):
        self.B()
        self.B()
        self.B()
