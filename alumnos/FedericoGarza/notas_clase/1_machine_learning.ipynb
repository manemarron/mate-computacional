# %%
#Ajuste de curvas

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

from IPython.html.widgets import interact, fixed
from IPython.html import widgets

# %%
# Regresión lineal

# %%
class RegresionLineal:
    def __init__(self, alpha, max_iters, tols):
        """
        Parámetros.
        ---------------
        alpha = Learning rate
        max_iters = Número máximo de iteraciones
        tols = definición de convergencia
        """
        self.alpha = alpha
        self.max_iters = max_iters
        self.tols = tols
        self.breaking_iteration = None
        self.historia = {'costo':[], 'beta':[]}  # Con fines de graficación
        
    def gradientDescent(self, x, y):
        """
        Parámetros:
        ---------------
        x = vector de entrenamiento de features
        y = vector de entrenamiento de variable a predecir (target)
        """    
        
        # ajustamos el vector de features
        unos = np.ones((x.shape[0], 1))
        Xt = X.reshape(x.shape[0], 1)
        Xt = np.concatenate((unos, Xt), axis=1)
        
        i = 0
        prep_J = 0
        m, n = Xt.shape
        self.beta = np.zeros(n) 
        
        while i < self.max_iters:     
            # Actualizamos beta
            self.beta = self.beta - self.alpha * self.gradiente(Xt, y)
            
            J = self.costo(Xt, y)
            
            if abs(J - prep_J) <= self.tols:
                print 'La función convergió con beta: %s en la iteración %i' % ( str(self.beta), i )
                self.breaking_iteration = i
                break
            else:
                prep_J = J
            
            self.historia['costo'].append(J)
            self.historia['beta'].append(self.beta)                
            i += 1
    
    def hipotesis(self, x):
        return np.dot(x, self.beta)
    
    def costo(self, x, y):
        m = x.shape[0]
        error = self.hipotesis(x) - y
        return np.dot(error.T, error) / (2 * m) 
    
    def gradiente(self, x, y):
        m = x.shape[0]
        error = self.hipotesis(x) - y        
        return np.dot(x.T, error) / m

# %%
cat 'data/edad.dat'
# Out:
#    2.0658746e+00
#    2.3684087e+00
#    2.5399929e+00
#    2.5420804e+00
#    2.5490790e+00
#    2.7866882e+00
#    2.9116825e+00
#    3.0356270e+00
#    3.1146696e+00
#    3.1582389e+00
#    3.3275944e+00
#    3.3793165e+00
#    3.4122006e+00
#    3.4215823e+00
#    3.5315732e+00
#    3.6393002e+00
#    3.6732537e+00
#    3.9256462e+00
#    4.0498646e+00
#    4.2483348e+00
#    4.3440052e+00
#    4.3826531e+00
#    4.4230602e+00
#    4.6102443e+00
#    4.6881183e+00
#    4.9777333e+00
#    5.0359967e+00
#    5.0684536e+00
#    5.4161491e+00
#    5.4395623e+00
#    5.4563207e+00
#    5.5698458e+00
#    5.6015729e+00
#    5.6877617e+00
#    5.7215602e+00
#    5.8538914e+00
#    6.1978026e+00
#    6.3510941e+00
#    6.4797033e+00
#    6.7383791e+00
#    6.8637686e+00
#    7.0223387e+00
#    7.0782373e+00
#    7.1514232e+00
#    7.4664023e+00
#    7.5973874e+00
#    7.7440717e+00
#    7.7729662e+00
#    7.8264514e+00
#    7.9306356e+00

# %%
cat 'data/altura.dat'
# Out:
#    7.7918926e-01
#    9.1596757e-01
#    9.0538354e-01
#    9.0566138e-01
#    9.3898890e-01
#    9.6684740e-01
#    9.6436824e-01
#    9.1445939e-01
#    9.3933944e-01
#    9.6074971e-01
#    8.9837094e-01
#    9.1209739e-01
#    9.4238499e-01
#    9.6624578e-01
#    1.0526500e+00
#    1.0143791e+00
#    9.5969426e-01
#    9.6853716e-01
#    1.0766065e+00
#    1.1454978e+00
#    1.0340625e+00
#    1.0070009e+00
#    9.6683648e-01
#    1.0895919e+00
#    1.0634462e+00
#    1.1237239e+00
#    1.0323374e+00
#    1.0874452e+00
#    1.0702988e+00
#    1.1606493e+00
#    1.0778037e+00
#    1.1069758e+00
#    1.0971875e+00
#    1.1648603e+00
#    1.1411796e+00
#    1.0844156e+00
#    1.1252493e+00
#    1.1168341e+00
#    1.1970789e+00
#    1.2069462e+00
#    1.1251046e+00
#    1.1235672e+00
#    1.2132829e+00
#    1.2522652e+00
#    1.2497065e+00
#    1.1799706e+00
#    1.1897299e+00
#    1.3029934e+00
#    1.2601134e+00
#    1.2562267e+00

# %%
X = np.loadtxt('data/edad.dat')
Y = np.loadtxt('data/altura.dat')

# %%
plt.scatter(X,Y, label="data")
plt.xlabel('Edad (yr)')
plt.ylabel('Altura (m)')

# %%
# Widget para ver qué recta que mejor minimiza el error

# %%
def plotGuess(x, y, interceptor, pendiente):
    
    modelo = lambda x,b,m: b + m*x # función para graficar el modelo
    
    plt.scatter(x,y, label="data")
    plt.plot(x, modelo(x, interceptor, pendiente), label='Guess')
    plt.xlabel('Edad (yr)')
    plt.ylabel('Altura (m)')
    plt.legend(loc="best")

# %%
interact(plotGuess, x=fixed(X), y=fixed(Y), interceptor=(0,2,0.02), pendiente=(0,2, 0.02));

# %%
r = RegresionLineal(alpha=0.03, max_iters=10000, tols=0.0000001)
r.gradientDescent(X, Y)
r.beta
# Out:
# La función convergió con beta: [ 0.73300235  0.06700325] en la iteración 1190
# array([ 0.73300235,  0.06700325])

# %%
# Dibujar el modelo en cada iteración

# %%
def plotModelo(x,y,rl,iteracion):
    modelo = lambda x,b,m: b + m*x # función para graficar el modelo
    
    _beta = rl.historia['beta'][iteracion]

    fig, ax = plt.subplots(1,2, figsize=(10,6))
    ax[0].scatter(x,y, label="datos")
    ax[0].plot(x, modelo(x, _beta[0], _beta[1]), label="int: %1.2f, pen: %1.2f" % (_beta[0], _beta[1]))
    ax[0].set_xlabel('Edad (yr)')
    ax[0].set_ylabel('Altura (m)')
    ax[0].legend(loc="best")
    #ax[0].set_xlim(0, max(x))
    #ax[0].set_ylim(0, max(y))
    
    costo  = rl.historia['costo']
    
    iteraciones = [i for i in range(0, len(costo))]
    ax[1].plot(iteraciones, costo, 'g', label="costo")
    ax[1].plot(iteracion, costo[iteracion], 'or', label="iteracion")
    ax[1].set_xlabel('Iteraciones')
    ax[1].set_ylabel('Costo')
    ax[1].legend(loc="best")

# %%
plotModelo(X,Y, r, 100)

# %%
ultima_iteracion = (r.breaking_iteration - 1) if r.breaking_iteration else (r.max_iters - 1)

interact(plotModelo, x=fixed(X), y=fixed(Y), rl=fixed(r), iteracion=(0,ultima_iteracion,10));

# %%
# Modificando widget para que incluya alpha

# %%
r = RegresionLineal(alpha=0.06, max_iters=10000, tols=0.0000001)
r.gradientDescent(X, Y)
# Out:
# La función convergió con beta: [ 0.73804233  0.06608629] en la iteración 649

# %%
ultima_iteracion = (r.breaking_iteration - 1) if r.breaking_iteration else (r.max_iters - 1)

interact(plotModelo, x=fixed(X), y=fixed(Y), rl=fixed(r), iteracion=(0,ultima_iteracion,10));

# %%
class RegresionLineal:
    def __init__(self, alpha=0.3, max_iters=100, tols=0.001):
        """
        Parámetros.
        ---------------
        alpha = Learning rate
        max_iters = Número máximo de iteraciones
        tols = definición de convergencia
        """
        self.alpha = alpha
        self.max_iters = max_iters
        self.tols = tols
        self.breaking_iteration = None
        self.historia = {'costo':[], 'beta':[]}  # Con fines de graficación
        
    def gradientDescent(self, x, y):
        """
        Parámetros:
        ---------------
        x = vector de entrenamiento de features
        y = vector de entrenamiento de variable a predecir (target)
        """    
        
        # ajustamos el vector de features
        unos = np.ones((x.shape[0], 1))
        Xt = X.reshape(x.shape[0], 1)
        Xt = np.concatenate((unos, Xt), axis=1)
        
        i = 0
        prep_J = 0
        m, n = Xt.shape
        self.beta = np.zeros(n) 
        
        while i < self.max_iters:     
            # Actualizamos beta
            self.beta = self.beta - self.alpha * self.gradiente(Xt, y)
            
            J = self.costo(Xt, y)
            
            if abs(J - prep_J) <= self.tols:
                print 'La función convergió con beta: %s en la iteración %i' % ( str(self.beta), i )
                self.breaking_iteration = i
                break
            else:
                prep_J = J
            
            self.historia['costo'].append(J)
            self.historia['beta'].append(self.beta)                
            i += 1
    
    def hipotesis(self, x):
        return np.dot(x, self.beta)
    
    def costo(self, x, y):
        m = x.shape[0]
        error = self.hipotesis(x) - y
        return np.dot(error.T, error) / (2 * m) 
    
    def gradiente(self, x, y):
        m = x.shape[0]
        error = self.hipotesis(x) - y        
        return np.dot(x.T, error) / m
    
    def plotModelo(self, x,y,iteracion):
        modelo = lambda x,b,m: b + m*x # función para graficar el modelo
    
        _beta = self.historia['beta'][iteracion]

        fig, ax = plt.subplots(1,2, figsize=(10,6))
        ax[0].scatter(x,y, label="datos")
        ax[0].plot(x, modelo(x, _beta[0], _beta[1]), label="int: %1.2f, pen: %1.2f" % (_beta[0], _beta[1]))
        ax[0].set_xlabel('Edad (yr)')
        ax[0].set_ylabel('Altura (m)')
        ax[0].legend(loc="best")
        #ax[0].set_xlim(0, max(x))
        #ax[0].set_ylim(0, max(y))
    
        costo  = self.historia['costo']
    
        iteraciones = [i for i in range(0, len(costo))]
        ax[1].plot(iteraciones, costo, 'g', label="costo")
        ax[1].plot(iteracion, costo[iteracion], 'or', label="iteracion")
        ax[1].set_xlabel('Iteraciones')
        ax[1].set_ylabel('Costo')
        ax[1].legend(loc="best")

# %%
r = RegresionLineal(alpha=0.03, max_iters=10000, tols=0.0000001)
r.gradientDescent(X, Y)
r.plotModelo(X,Y,320)
# Out:
# La función convergió con beta: [ 0.73300235  0.06700325] en la iteración 1190

# %%
def cambiar_alpha(Alpha):
    r = RegresionLineal(alpha=Alpha, max_iters=10000, tols=0.0000001)
    r.gradientDescent(X, Y)
    r.plotModelo(X,Y,400)

# %%
interact(cambiar_alpha, Alpha = (0.001,0.1,0.001))
# Out:
# La función convergió con beta: [ 0.73688831  0.06629625] en la iteración 762
# <function __main__.cambiar_alpha>

# %%
ultima_iteracion = (r.breaking_iteration - 1) if r.breaking_iteration else (r.max_iters - 1)

interact(plotModelo, x=fixed(X), y=fixed(Y), rl=r.plotModelo(fixed(X), fixed(Y), fixed(3)), iteracion=(0,ultima_iteracion,10));
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-9c76752b36af> in <module>()
#       1 ultima_iteracion = (r.breaking_iteration - 1) if r.breaking_iteration else (r.max_iters - 1)
#       2
# ----> 3 interact(plotModelo, x=fixed(X), y=fixed(Y), rl=r.plotModelo(fixed(X), fixed(Y), fixed(3)), iteracion=(0,ultima_iteracion,10));
#
# <ipython-input-20-fa700e8883d9> in plotModelo(self, x, y, iteracion)
#      66         modelo = lambda x,b,m: b + m*x # función para graficar el modelo
#      67
# ---> 68         _beta = self.historia['beta'][iteracion]
#      69
#      70         fig, ax = plt.subplots(1,2, figsize=(10,6))
#
# TypeError: list indices must be integers, not fixed
