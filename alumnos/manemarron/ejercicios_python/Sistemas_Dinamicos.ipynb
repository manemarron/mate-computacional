# %% [markdown]
# # Sistemas Dinámicos

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# El código siguiente recarga (reloads) las rutinas externas cada vez que el código cambia (es útil para "debuggear" código externo)

# %load_ext autoreload
# %autoreload 2

# %%
# Realiza division flotante
from __future__ import division

# %%
# %%writefile euler.py
import numpy as np
def euler(y,dy,tau,N):
    dt = tau / float(N-1)
    for t in xrange(N-1):
        y[t+1]=y[t] + dy(y[t])*dt
    return y
# Out:
# Writing euler.py

# %%
from euler import *

# %% [markdown]
# ## Caida libre

# %%
tau = 3.0
N = 1000
y=np.zeros([N,2],dtype=np.float128)
y[0,0]=0.0
y[0,1]=0.0
dy = lambda y: np.array([y[1],-9.8])

# %%
y=euler(y,dy,tau,N)

# %%
xdata = [y[j,0] for j in range(N)]
vdata = [y[j,1] for j in range(N)]

plt.plot(t, xdata, label="pos")
plt.plot(t, vdata, label="vel")
plt.xlabel("tiempo")
plt.ylabel("posicion, velocidad")
plt.legend(loc="best")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a3f5fbb355a4> in <module>()
#       2 vdata = [y[j,1] for j in range(N)]
#       3
# ----> 4 plt.plot(t, xdata, label="pos")
#       5 plt.plot(t, vdata, label="vel")
#       6 plt.xlabel("tiempo")
#
# NameError: name 't' is not defined

# %% [markdown]
# ## Péndulo

# %%
# %%writefile pendulo.py
import numpy as np

class Pendulo:
    
    def __init__(self, masa, longitud, gravedad):
        self.masa = masa
        self.longitud = longitud
        self.gravedad = gravedad
      
        self.Omega = sqrt(g/longitud)
        self.period = 2*np.pi/Omega

        
    def theta(self):
        return self.trajectory[:,0]
    
    def omega(self):
        return self.trajectory[:,1]
    
    def plot(self):
        fig, ax = plt.subplots(3,1, figsize=(10,8), sharex = True)

        ax[0].plot(self.tau, self.theta(), label="theta", color="blue")
        ax[1].plot(self.tau, self.omega(), label="omega", color="green")
        ax[2].plot(self.tau, self.energy(),  marker='o', linestyle='None', color='red', label="Energia")

        ax[0].set_ylabel("Theta (rads)")
        ax[0].set_xlabel("tiempo (s)")

        ax[1].set_ylabel("Omega (rads/s)")
        ax[1].set_xlabel("tiempo (s)")

        ax[2].set_ylabel("Energia (J)")
        ax[2].set_xlabel("tiempo (s)")
    
    def initial_conditions(self, theta_i, omega_i):
        self.theta_i = theta_i
        self.omega_i = omega_i
        
    def dynamics(self, state, t):
        g0 = state[1]
        g1 = -self.gravedad/self.longitud*state[0]
        return np.array([g0, g1])
        
    def energy(self):
        return 0.5*self.masa*self.longitud**2 * (self.omega()**2 + (self.gravedad/self.longitud)*self.theta()**2)
        
    def integrate(self, num_steps, t_i, t_f, method):
        
        self.tau, self.dt = np.linspace(t_i, t_f, num=num_steps, retstep=True)
        self.trajectory = np.zeros([num_steps, 2])
        self.trajectory[0,0] = self.theta_i
        self.trajectory[0,1] = self.omega_i
        
        for j in range(num_steps-1):
            self.trajectory[j+1] = method(self.trajectory[j], self.tau[j], self.dt, self.dynamics)

# %%
from pendulo import Pendulo

# %%
p = Pendulo(1.0,1.0,9.8)
N=1000
theta = np.zeros(N)
theta[0]=0.2
omega=0.0
time = np.linspace(0,4.0,N)
theta = p.analytic_position(time,theta[0],omega)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-bd644c7c2a33> in <module>()
# ----> 1 p = Pendulo(1.0,1.0,9.8)
#       2 N=1000
#       3 theta = np.zeros(N)
#       4 theta[0]=0.2
#       5 omega=0.0
#
# NameError: name 'Pendulo' is not defined

# %%
plt.plot(time,theta)
plt.xlabel("Tiempo")
plt.ylabel("Theta")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b16cdd0c0c79> in <module>()
# ----> 1 plt.plot(time,theta)
#       2 plt.xlabel("Tiempo")
#       3 plt.ylabel("Theta")
#
# NameError: name 'time' is not defined

# %%
p = Pendulo(1.0,1.0,9.8)
tau = 5 * p.T 
N = 100
time = np.linspace(0,tau,N)
y = np.zeros([N,2])
y[0]=np.array([0.2,0.0])
theta = np.zeros(N)
theta[0]=0.2
omega=0.0
y = p.euler_position(y,tau,N)
theta = p.analytic_position(time,theta[0],omega)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3c55b68e2ac7> in <module>()
# ----> 1 p = Pendulo(1.0,1.0,9.8)
#       2 tau = 5 * p.T
#       3 N = 100
#       4 time = np.linspace(0,tau,N)
#       5 y = np.zeros([N,2])
#
# NameError: name 'Pendulo' is not defined

# %%
plt.plot(time,y[:,0],label="theta_euler")
plt.plot(time,y[:,1],label="omega")
plt.plot(time,theta,label="theta_analitica")
plt.xlabel("Tiempo")
plt.ylabel("Theta, Omega")
plt.legend(loc="best")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-117eb3a4aa0f> in <module>()
# ----> 1 plt.plot(time,y[:,0],label="theta_euler")
#       2 plt.plot(time,y[:,1],label="omega")
#       3 plt.plot(time,theta,label="theta_analitica")
#       4 plt.xlabel("Tiempo")
#       5 plt.ylabel("Theta, Omega")
#
# NameError: name 'time' is not defined

# %% [markdown]
# ## Runge-Kutta

# %%
from python_modules.pendulo import *

# %%
def RK2(y, t, dt, derivadas):
    k0 = dt*derivadas(y, t)
    k1 = dt*derivadas(y + k0, t + dt)
    y_next = y + 0.5*(k0 + k1)
    
    return y_next

# %%
p2 = PenduloReal(masa = 1.0, longitud = 1.0, gravedad = 9.8)
p2.initial_conditions(theta_i=0.2, omega_i=0.0)

# %%
N = 1000
tiempo_inicial = 0.0
tiempo_final = 5*p2.period

# %%
p2.integrate(N, tiempo_inicial, tiempo_final, RK2)
p2.plot()

# %%
p2.plot_phase_diagram()

# %%
p2 = PenduloActuado(masa = 1.0, longitud = 1.0, gravedad = 9.8, beta=1, A=1, frequency=1)
p2.initial_conditions(theta_i=0.2, omega_i=0.0)

# %%
N = 1000
tiempo_inicial = 0.0
tiempo_final = 5*p2.period

# %%
p2.integrate(N, tiempo_inicial, tiempo_final, RK2)
p2.plot()

# %%
p2.plot_phase_diagram()

# %%
p = PenduloResorte(0.2,1.0,9.8,3.5)

# %%
N = 1000

L = 1.0
v_i = 0.0
theta_i = 0.3
omega_i = 0.0

y = np.zeros([L, v_i, theta_i, omega_i])
time = np.linspace(0,25,N)

# %%
p.integrate(y,time)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a131099ea540> in <module>()
# ----> 1 p.integrate(y,time)
#
# /home/itam/proyectos/mate-computacional/alumnos/manemarron/ejercicios_python/python_modules/pendulo/pendulo_resorte.py in integrate(self, y, time)
#      21
#      22     def integrate(self, y, time):
# ---> 23         print odeint(func=self.dynamics, y0=y, t=time)
#
# /usr/local/lib/python2.7/dist-packages/scipy/integrate/odepack.pyc in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg)
#     146     output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     147                              full_output, rtol, atol, tcrit, h0, hmax, hmin,
# --> 148                              ixpr, mxstep, mxhnil, mxordn, mxords)
#     149     if output[-1] < 0:
#     150         print(_msgs[output[-1]])
#
# ValueError: object too deep for desired array
