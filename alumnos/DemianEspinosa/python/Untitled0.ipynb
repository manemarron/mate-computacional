# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import random
import copy
import pdb
from collections import *
  
Coord = namedtuple('Coord', 'r c')
Move = namedtuple('Move', 'pos player')
  
def flatten(x):
    return [inner for outer in x for inner in outer]
  
class Board():
    def __init__(self):
        self.b = [['' for x in range(3)] for x in range(3)]
  
    def winner(self):
        # yes, this is lazy.
        for p in ['X', 'O']:
            for r in range(3):
                if all(x == p for x in self.b[r]):
                    return p
  
            for c in range(3):
                if all(r[c] == p for r in self.b):
                    return p
  
            if self.b[0][0] == p and self.b[1][1] == p and self.b[2][2] == p:
                return p
  
            if self.b[0][2] == p and self.b[1][1] == p and self.b[2][0] == p:
                return p
  
        return 'T' if self.full() else ''
  
    def full(self):
        return not any(x == '' for x in flatten(self.b))
  
    def count(self):
        return sum(int(x != '') for x in flatten(self.b))
  
    def randomEmptyCoord(self):
        if self.full():
            raise ValueError('No empty spots')
        while True:
            r, c = random.randint(0,2), random.randint(0,2)
            if self.b[r][c] == '':
                return Coord(r,c)
  
    def set(self, r, c, m):
        if self.b[r][c] != '':
            raise Exception('wat')
        self.b[r][c] = m
  
    def get(self, r, c):
        return self.b[r][c]
  
    def draw(self):
        for r in range(3):
            for c in range(3):
                print (self.b[r][c] if self.b[r][c] != '' else ' '),
            print
  
  
class Player:
    def __init__(self):
        self.mark = 'W'
  
    def play(self, board, history):
        pass
  
class BelowPlayer(Player):
    def __str__(self):
        return 'BelowPlayer'
  
    # If the position below is available, play there.
    # Otherwise, play a random move.
    def play(self, board, history):
        if len(history) != 0:
            p = history[-1].pos
        else:
            p = board.randomEmptyCoord()
  
        if board.get((p.r + 2)%3, p.c) == '':
            return Coord((p.r + 2) % 3, p.c)
        else:
            return board.randomEmptyCoord()
  
class RandomPlayer(Player):
    def __str__(self):
        return 'RandomPlayer'
  
    def play(self, board, history):
            return board.randomEmptyCoord()
  
class PureMonteCarloPlayer(Player):
    def __str__(self):
        return 'PureMonteCarloPlayer'
  
    def play(self, board, history):
        bestSoFar, bestWins = board.randomEmptyCoord(), 0
  
        for r in range(2):
            for c in range(2):
                if not board.get(r,c):
                    cnt = 0
  
                    for k in range(100):
                            board_ = copy.deepcopy(board)
                            board_.set(r, c, self.mark)
                            game = Game(RandomPlayer(), RandomPlayer(), startBoard = board_)
                            if game.playGame() == self.mark:
                                cnt += 1
  
                    if cnt > bestWins:
                        bestSoFar = Coord(r,c)
                        bestWins = cnt
  
        return bestSoFar
  
  
class Game:
    def __init__(self, playerA, playerB, startBoard = None):
        self.history = []
  
        self.board = startBoard or Board()
  
        playerA.mark = 'X'
        playerB.mark = 'O'
  
        self.players = [playerA, playerB]
  
    def playGame(self):
        t = self.board.count()
  
        while self.board.winner() == '':
            p = self.players[t%2].play(self.board, self.history)
            self.history.append(Move(p, self.players[t%2].mark))
            self.board.set(p.r, p.c, self.players[t%2].mark)
            t += 1
  
        return self.board.winner()
  
def plotDif(results):
    plt.figure(figsize = (6,6))
    time = np.arange(len(results) +  1)
    dif = [0]
    for i in range(len(results)):
        if results[i] == 'T':
                dif.append(dif[i])
        elif results[i] == 'X':
                dif.append(dif[i] + 1)
        else:
                dif.append(dif[i] - 1)
    dif = np.array(dif)    
     
    plt.plot(time, dif)
    plt.xlabel('# Partida')
    plt.ylabel('Dif de A respecto a B')
    plt.title("Dif A vs B")
    plt.show()
 
#plotDif('XXXOTXOTOXOOTOXOOOXOTOXOOTOXOTOXOTOOOOOOOTTTTTTTTTXOXOX')
 
def plotPie(results):
    A = B = T = 0
    for i in range(len(results)):
        if results[i] == 'T':
                T += 1
        elif results[i] == 'X':
                A += 1
        else:
                B += 1   
                 
    #make a square figure and axes
    plt.figure(1, figsize=(6,6))
    ax = plt.axes([0.1, 0.1, 0.8, 0.8])
 
    # The slices will be ordered and plotted counter-clockwise.
    labels = 'Player A', 'Player B', 'Ties'
    fracs = [A, B, T]
    plt.pie(fracs,labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
             
    plt.title('Final A vs B', bbox={'facecolor':'0.8', 'pad':5})
    plt.show()
 
#plotPie('XXXOTXOTTTTTOXOOTOXOOOXOTTTTTTOXOOTOXOTOXOTOOOOOOOTTTTTTTTTX')
 
  
# Example game.
game = Game(RandomPlayer(), BelowPlayer())
print game.playGame(), "wins!"
game.board.draw()

  
N = 50 # how many games to play
  
playerClasses = [RandomPlayer, BelowPlayer, PureMonteCarloPlayer]
  
for x in playerClasses:
    for o in playerClasses:
        # Start with a fresh instance every time.
        X = x()
        O = o()
        x_wins = 0
        o_wins = 0
        ties = 0
        record = ""
  
        for k in range(N):
            game = Game(X, O)
            winner = game.playGame()
            record += winner
            if winner == "X":
                x_wins += 1
            elif winner == "O":
                o_wins += 1
            else:
                ties += 1
             
        print X, "vs", O, ":", x_wins, "-", o_wins, "-", ties
        print record
        print
        plotDif(record)
        plotPie(record)
# Out:
# X wins!
# X   O
# X X O
# O   X
# RandomPlayer vs RandomPlayer : 21 - 18 - 11
# OOOTXOTOOTOXOOOOXTOXXTTTXXXOXXOXTTXOXOXXOXXXXTXOTX
# RandomPlayer vs BelowPlayer : 28 - 12 - 10
# OXOOOOXXXXXTXTXTTXXOOOOXTXXXTXXXXXTOOXTXTXOXXXXTXX
# RandomPlayer vs PureMonteCarloPlayer : 26 - 24 - 0
# XOOXXXOXXXXXXOXOOXOXXXOXXXOOXOOXXXXXOXOOOOOXOOOOOO
# BelowPlayer vs RandomPlayer : 23 - 20 - 7
# OOTXOXOXTXOXOXOOTXOXXXOTXXOOXOOXOTTXTXOXXXXOXXOXOO
# BelowPlayer vs BelowPlayer : 27 - 11 - 12
# XXOOXOXXXTTTXOTXOXOTTXXOXXXXXXOXTTXXXOTTXTXXXXOTOX
# BelowPlayer vs PureMonteCarloPlayer : 17 - 23 - 10
# XOOXOOTXXXXXTXOXOTOOXXOXOXOTXTOOOTTOXOXOTOOOTOOOXT
# PureMonteCarloPlayer vs RandomPlayer : 35 - 13 - 2
# XXXXXXXXXXTOXXXOXXXXXXXXXOOXXXOTXXOXXOXXOOXXOXOOOX
# PureMonteCarloPlayer vs BelowPlayer : 35 - 8 - 7
# OXOXXOOXXTXXXXXXTXXXOXTXTXOXOTTXXXXXXTXXXXXXXXXOXX
# PureMonteCarloPlayer vs PureMonteCarloPlayer : 29 - 16 - 5
# XXOXXTXOXOXXTOTOXXTOXXXOXOXOTXOXOXXXOXXXXXOXOXXOXO
